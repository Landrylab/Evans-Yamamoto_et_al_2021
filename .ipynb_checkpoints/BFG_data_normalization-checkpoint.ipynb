# %%
# coding: utf-8
import ast
import os
import sys
import re
from pprint import pprint
import numpy as np
from tqdm import tqdm

from func import normalization as norm

##############################################
# JUPYTER-NOTEBOOK FOR NORMALIZING BARCODE   #
# COUNTS FROM BFG-PCA SCREENINGS             #
# Last modified by Daniel Evans-Yamamoto     #
##############################################

PATH = os.path.abspath(".")
run_name = "test"
norm_dir = '%s/Data/%s/normalization'%(PATH,run_name)
stats_dir = '%s/Data/%s/stats'%(PATH,run_name)
if not os.path.isdir(norm_dir):
    os.makedirs(norm_dir)
    os.makedirs(stats_dir)

# %%
#  Definfing the file location
count_f        = "%s/Data/%s/barcode_counts/counts.txt"%(PATH,run_name)

#  Reading dict object from the text files with count data
count     = norm.reading(count_f)
# Reading tag information and barcode database 
multiplex_tag  = norm.get_tagdata('%s/%s/%s_tag.csv'%(PATH,run_name,run_name))#Change this to your own file. Read wiki for instructions.
db             = norm.get_mapdata('%s/%s/%s_database.csv'%(PATH,run_name,run_name))#Change this to your own file. Read wiki for instructions.

# %%
# Examine total reads;
norm.tot_reads(count,multiplex_tag)
# Out:
# Index Sample Total reads
# P01-P01 DMSO_72 26688
# P02-P02 DMSO_96 20268
# P03-P03 MTX1_72 31386
# P04-P04 MTX1_96 17517
# P05-P05 MTX10_72 59666
# P06-P06 MTX10_96 48641
# P07-P07 MTX100_72 80752
# P08-P08 MTX100_96 70757
# P09-P09 MTX200_72 63668
# P10-P10 MTX200_96 68431

# %%
#pprint(count)

# %%
# Organize dict of reads per strain
count_2 =  norm.organize_data(count,db,multiplex_tag,"PCA")
# Out:
# Working on ...
# P01-P01 Control_1
# P03-P03 MTX1_72_PRS
# P05-P05 MTX10_72_PRS
# P07-P07 MTX100_72_PRS
# P09-P09 MTX200_72_PRS
# P02-P02 Control_2
# P04-P04 MTX1_96_PRS
# P06-P06 MTX10_96_PRS
# P08-P08 MTX100_96_PRS
# P10-P10 MTX200_96_PRS

# %%
pprint(count_2)
# Out:
# {'Control_1': {'DHFR3_ScPRS_03': {'DHFR12_ScPRS_01': {'BC1': {'BC1': {'DnDn': {'count': 165,
#                                                                                'raw': 164},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 79,
#                                                                                'raw': 78},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_02': {'BC1': {'BC1': {'DnDn': {'count': 56,
#                                                                                'raw': 55},
#                                                                       'UpUp': {'count': 50,
#                                                                                'raw': 49}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 26,
#                                                                                'raw': 25},
#                                                                       'UpUp': {'count': 9,
#                                                                                'raw': 8}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_03': {'BC1': {'BC1': {'DnDn': {'count': 130,
#                                                                                'raw': 129},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 52,
#                                                                                'raw': 51},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_04': {'BC1': {'BC1': {'DnDn': {'count': 76,
#                                                                                'raw': 75},
#                                                                       'UpUp': {'count': 60,
#                                                                                'raw': 59}},
#                                                               'BC2': {'DnDn': {'count': 128,
#                                                                                'raw': 127},
#                                                                       'UpUp': {'count': 105,
#                                                                                'raw': 104}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 42,
#                                                                                'raw': 41},
#                                                                       'UpUp': {'count': 26,
#                                                                                'raw': 25}},
#                                                               'BC2': {'DnDn': {'count': 44,
#                                                                                'raw': 43},
#                                                                       'UpUp': {'count': 30,
#                                                                                'raw': 29}}}},
#                                   'DHFR12_ScPRS_05': {'BC1': {'BC1': {'DnDn': {'count': 31,
#                                                                                'raw': 30},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 25,
#                                                                                'raw': 24},
#                                                                       'UpUp': {'count': 20,
#                                                                                'raw': 19}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 2,
#                                                                                'raw': 1},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 13,
#                                                                                'raw': 12},
#                                                                       'UpUp': {'count': 3,
#                                                                                'raw': 2}}}},
#                                   'DHFR12_ScPRS_06': {'BC1': {'BC1': {'DnDn': {'count': 289,
#                                                                                'raw': 288},
#                                                                       'UpUp': {'count': 285,
#                                                                                'raw': 284}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 129,
#                                                                                'raw': 128},
#                                                                       'UpUp': {'count': 79,
#                                                                                'raw': 78}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_07': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 29,
#                                                                                'raw': 28},
#                                                                       'UpUp': {'count': 54,
#                                                                                'raw': 53}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 17,
#                                                                                'raw': 16},
#                                                                       'UpUp': {'count': 13,
#                                                                                'raw': 12}}}},
#                                   'DHFR12_ScPRS_08': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 21,
#                                                                                'raw': 20},
#                                                                       'UpUp': {'count': 13,
#                                                                                'raw': 12}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 3,
#                                                                                'raw': 2},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_09': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 110,
#                                                                                'raw': 109},
#                                                                       'UpUp': {'count': 105,
#                                                                                'raw': 104}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 30,
#                                                                                'raw': 29},
#                                                                       'UpUp': {'count': 25,
#                                                                                'raw': 24}}}},
#                                   'DHFR12_ScPRS_10': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_11': {'BC1': {'BC1': {'DnDn': {'count': 74,
#                                                                                'raw': 73},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 74,
#                                                                                'raw': 73},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 39,
#                                                                                'raw': 38},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 30,
#                                                                                'raw': 29},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_12': {'BC1': {'BC1': {'DnDn': {'count': 165,
#                                                                                'raw': 164},
#                                                                       'UpUp': {'count': 111,
#                                                                                'raw': 110}},
#                                                               'BC2': {'DnDn': {'count': 178,
#                                                                                'raw': 177},
#                                                                       'UpUp': {'count': 25,
#                                                                                'raw': 24}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 29,
#                                                                                'raw': 28},
#                                                                       'UpUp': {'count': 20,
#                                                                                'raw': 19}},
#                                                               'BC2': {'DnDn': {'count': 61,
#                                                                                'raw': 60},
#                                                                       'UpUp': {'count': 5,
#                                                                                'raw': 4}}}},
#                                   'DHFR12_ScPRS_13': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 120,
#                                                                                'raw': 119}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 44,
#                                                                                'raw': 43}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 66,
#                                                                                'raw': 65}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 24,
#                                                                                'raw': 23}}}},
#                                   'DHFR12_ScPRS_14': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 45,
#                                                                                'raw': 44},
#                                                                       'UpUp': {'count': 41,
#                                                                                'raw': 40}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 14,
#                                                                                'raw': 13},
#                                                                       'UpUp': {'count': 15,
#                                                                                'raw': 14}}}}},
#                'DHFR3_ScPRS_04': {'DHFR12_ScPRS_01': {'BC1': {'BC1': {'DnDn': {'count': 57,
#                                                                                'raw': 56},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_02': {'BC1': {'BC1': {'DnDn': {'count': 20,
#                                                                                'raw': 19},
#                                                                       'UpUp': {'count': 6,
#                                                                                'raw': 5}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_03': {'BC1': {'BC1': {'DnDn': {'count': 37,
#                                                                                'raw': 36},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_04': {'BC1': {'BC1': {'DnDn': {'count': 15,
#                                                                                'raw': 14},
#                                                                       'UpUp': {'count': 20,
#                                                                                'raw': 19}},
#                                                               'BC2': {'DnDn': {'count': 56,
#                                                                                'raw': 55},
#                                                                       'UpUp': {'count': 34,
#                                                                                'raw': 33}}}},
#                                   'DHFR12_ScPRS_05': {'BC1': {'BC1': {'DnDn': {'count': 8,
#                                                                                'raw': 7},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 8,
#                                                                                'raw': 7},
#                                                                       'UpUp': {'count': 7,
#                                                                                'raw': 6}}}},
#                                   'DHFR12_ScPRS_06': {'BC1': {'BC1': {'DnDn': {'count': 80,
#                                                                                'raw': 79},
#                                                                       'UpUp': {'count': 68,
#                                                                                'raw': 67}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_07': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 20,
#                                                                                'raw': 19},
#                                                                       'UpUp': {'count': 14,
#                                                                                'raw': 13}}}},
#                                   'DHFR12_ScPRS_08': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 5,
#                                                                                'raw': 4}}}},
#                                   'DHFR12_ScPRS_09': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 27,
#                                                                                'raw': 26},
#                                                                       'UpUp': {'count': 18,
#                                                                                'raw': 17}}}},
#                                   'DHFR12_ScPRS_10': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_11': {'BC1': {'BC1': {'DnDn': {'count': 17,
#                                                                                'raw': 16},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 32,
#                                                                                'raw': 31},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_12': {'BC1': {'BC1': {'DnDn': {'count': 37,
#                                                                                'raw': 36},
#                                                                       'UpUp': {'count': 28,
#                                                                                'raw': 27}},
#                                                               'BC2': {'DnDn': {'count': 74,
#                                                                                'raw': 73},
#                                                                       'UpUp': {'count': 5,
#                                                                                'raw': 4}}}},
#                                   'DHFR12_ScPRS_13': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 33,
#                                                                                'raw': 32}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 15,
#                                                                                'raw': 14}}}},
#                                   'DHFR12_ScPRS_14': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 42,
#                                                                                'raw': 41},
#                                                                       'UpUp': {'count': 20,
#                                                                                'raw': 19}}}}},
#                'DHFR3_ScPRS_05': {'DHFR12_ScPRS_01': {'BC1': {'BC1': {'DnDn': {'count': 216,
#                                                                                'raw': 215},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_02': {'BC1': {'BC1': {'DnDn': {'count': 88,
#                                                                                'raw': 87},
#                                                                       'UpUp': {'count': 57,
#                                                                                'raw': 56}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_03': {'BC1': {'BC1': {'DnDn': {'count': 185,
#                                                                                'raw': 184},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_04': {'BC1': {'BC1': {'DnDn': {'count': 98,
#                                                                                'raw': 97},
#                                                                       'UpUp': {'count': 53,
#                                                                                'raw': 52}},
#                                                               'BC2': {'DnDn': {'count': 146,
#                                                                                'raw': 145},
#                                                                       'UpUp': {'count': 96,
#                                                                                'raw': 95}}}},
#                                   'DHFR12_ScPRS_05': {'BC1': {'BC1': {'DnDn': {'count': 23,
#                                                                                'raw': 22},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 38,
#                                                                                'raw': 37},
#                                                                       'UpUp': {'count': 19,
#                                                                                'raw': 18}}}},
#                                   'DHFR12_ScPRS_06': {'BC1': {'BC1': {'DnDn': {'count': 448,
#                                                                                'raw': 447},
#                                                                       'UpUp': {'count': 249,
#                                                                                'raw': 248}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_07': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 70,
#                                                                                'raw': 69},
#                                                                       'UpUp': {'count': 48,
#                                                                                'raw': 47}}}},
#                                   'DHFR12_ScPRS_08': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 18,
#                                                                                'raw': 17},
#                                                                       'UpUp': {'count': 12,
#                                                                                'raw': 11}}}},
#                                   'DHFR12_ScPRS_09': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 125,
#                                                                                'raw': 124},
#                                                                       'UpUp': {'count': 87,
#                                                                                'raw': 86}}}},
#                                   'DHFR12_ScPRS_10': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_11': {'BC1': {'BC1': {'DnDn': {'count': 84,
#                                                                                'raw': 83},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 126,
#                                                                                'raw': 125},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_12': {'BC1': {'BC1': {'DnDn': {'count': 196,
#                                                                                'raw': 195},
#                                                                       'UpUp': {'count': 92,
#                                                                                'raw': 91}},
#                                                               'BC2': {'DnDn': {'count': 244,
#                                                                                'raw': 243},
#                                                                       'UpUp': {'count': 21,
#                                                                                'raw': 20}}}},
#                                   'DHFR12_ScPRS_13': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 141,
#                                                                                'raw': 140}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 58,
#                                                                                'raw': 57}}}},
#                                   'DHFR12_ScPRS_14': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 73,
#                                                                                'raw': 72},
#                                                                       'UpUp': {'count': 34,
#                                                                                'raw': 33}}}}},
#                'DHFR3_ScPRS_06': {'DHFR12_ScPRS_01': {'BC1': {'BC1': {'DnDn': {'count': 144,
#                                                                                'raw': 143},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 90,
#                                                                                'raw': 89},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_02': {'BC1': {'BC1': {'DnDn': {'count': 44,
#                                                                                'raw': 43},
#                                                                       'UpUp': {'count': 38,
#                                                                                'raw': 37}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 27,
#                                                                                'raw': 26},
#                                                                       'UpUp': {'count': 25,
#                                                                                'raw': 24}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_03': {'BC1': {'BC1': {'DnDn': {'count': 83,
#                                                                                'raw': 82},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 72,
#                                                                                'raw': 71},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 1,
#                                                                                'raw': 0},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}}}},
#                                   'DHFR12_ScPRS_04': {'BC1': {'BC1': {'DnDn': {'count': 36,
#                                                                                'raw': 35},
#                                                                       'UpUp': {'count': 31,
#                                                                                'raw': 30}},
#                                                               'BC2': {'DnDn': {'count': 101,
#                                                                                'raw': 100},
#                                                                       'UpUp': {'count': 63,
#                                                                                'raw': 62}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 32,
#                                                                                'raw': 31},
#                                                                       'UpUp': {'count': 14,
#                                                                                'raw': 13}},
#                                                               'BC2': {'DnDn': {'count': 65,
#                                                                                'raw': 64},
#                                                                       'UpUp': {'count': 37,
#                                                                                'raw': 36}}}},
#                                   'DHFR12_ScPRS_05': {'BC1': {'BC1': {'DnDn': {'count': 27,
#                                                                                'raw': 26},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
#                                                               'BC2': {'DnDn': {'count': 25,
#                                                                                'raw': 24},
#                                                                       'UpUp': {'count': 7,
#                                                                                'raw': 6}}},
#                                                       'BC2': {'BC1': {'DnDn': {'count': 8,
#                                                                                'raw': 7},
#                                                                       'UpUp': {'count': 1,
#                                                                                'raw': 0}},
# ...
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}},
#                                     'DHFR12_ScPRS_08': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 5,
#                                                                                  'raw': 4},
#                                                                         'UpUp': {'count': 9,
#                                                                                  'raw': 8}}},
#                                                         'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}},
#                                     'DHFR12_ScPRS_09': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 44,
#                                                                                  'raw': 43},
#                                                                         'UpUp': {'count': 42,
#                                                                                  'raw': 41}}},
#                                                         'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}},
#                                     'DHFR12_ScPRS_10': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}},
#                                                         'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}},
#                                     'DHFR12_ScPRS_11': {'BC1': {'BC1': {'DnDn': {'count': 34,
#                                                                                  'raw': 33},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 30,
#                                                                                  'raw': 29},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}},
#                                                         'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}},
#                                     'DHFR12_ScPRS_12': {'BC1': {'BC1': {'DnDn': {'count': 60,
#                                                                                  'raw': 59},
#                                                                         'UpUp': {'count': 63,
#                                                                                  'raw': 62}},
#                                                                 'BC2': {'DnDn': {'count': 83,
#                                                                                  'raw': 82},
#                                                                         'UpUp': {'count': 19,
#                                                                                  'raw': 18}}},
#                                                         'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}},
#                                     'DHFR12_ScPRS_13': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 54,
#                                                                                  'raw': 53}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 24,
#                                                                                  'raw': 23}}},
#                                                         'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}},
#                                     'DHFR12_ScPRS_14': {'BC1': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 24,
#                                                                                  'raw': 23},
#                                                                         'UpUp': {'count': 17,
#                                                                                  'raw': 16}}},
#                                                         'BC2': {'BC1': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}},
#                                                                 'BC2': {'DnDn': {'count': 1,
#                                                                                  'raw': 0},
#                                                                         'UpUp': {'count': 1,
#                                                                                  'raw': 0}}}}},
#                  'DHFR3_ScPRS_13': {
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c83b67d4caa4> in <module>
# ----> 1 pprint(count_2)
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in pprint(object, stream, indent, width, depth, compact)
#      51         stream=stream, indent=indent, width=width, depth=depth,
#      52         compact=compact)
# ---> 53     printer.pprint(object)
#      54
#      55 def pformat(object, indent=1, width=80, depth=None, *, compact=False):
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in pprint(self, object)
#     137
#     138     def pprint(self, object):
# --> 139         self._format(object, self._stream, 0, 0, {}, 0)
#     140         self._stream.write("\n")
#     141
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     180     def _pprint_dict(self, object, stream, indent, allowance, context, level):
#     181         write = stream.write
# --> 182         write('{')
#     183         if self._indent_per_level > 1:
#     184             write((self._indent_per_level - 1) * ' ')
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Eliminating strains present in less than 90% of diploids

count_3 = norm.absent(count_2,0.9,"PCA")

count_sums = norm.get_sums(count_3,multiplex_tag,"PCA",db)

# %%
# Normalize scores based on strain abundance of bait and prey haploids in Control condition

raw_s,hap_s  = norm.compute_s(count_3,count_sums,db,multiplex_tag,"PCA")

# %%
# Organizing data and counting haploid strains
reps= norm.count_haploids(hap_s,norm_dir,db)
norm.haploid_replicates(reps,norm_dir)
# Out:
# Control_1 		Bait: , (15 ORFs) 21 Prey, (13 ORFs) 18
# Control_2 		Bait: , (15 ORFs) 21 Prey, (13 ORFs) 18
# Generated : /Users/danyamamotoevans/GitHub/BFG/Data/test/normalization/Haploid_F.csv
# Generated : /Users/danyamamotoevans/GitHub/BFG/Data/test/normalization/haplliod_n.csv

# %%
## Normalize signal 's'
## For Y2H ; Normalize data by Nth quantile of bait 'median distribution' of 's' score
## For PCA ; Normalize data by median 's' score of both bait and prey 

normalized_score,hap_s = norm.compute_ds(raw_s,count_sums,db,multiplex_tag,"PCA")

# %%
norm.output_norm_score(normalized_score,db,norm_dir)
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 150.34it/s]
# Generated : /Users/danyamamotoevans/GitHub/BFG/Data/test/normalization/BFG-PCA_PPI_scores_Normalized.csv

# %%
norm.output_stats(data,db,norm_dir)
